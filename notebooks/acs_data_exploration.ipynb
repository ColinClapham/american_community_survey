# %%
from scripts.utils import read_config
from scripts.get_acs_data import extract_acs_data

# %%
acs_data_2018 = extract_acs_data(read_config('../config.toml')['ACS_API_KEY'])
# Out:
# 2023-03-20 12:05:42.986 | INFO     | scripts.get_acs_data:extract_acs_data:175 - extracting acs data for 2018
# /Users/cclapham/bitbucket/personal_github/american_community_survey/scripts/get_acs_data.py:190: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   census_output = census_output.append(tmp, ignore_index=True)
# 2023-03-20 12:09:08.443 | INFO     | scripts.get_acs_data:extract_acs_data:198 - extraction for 2018 finished!
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 acs_data_2018 = extract_acs_data(read_config('../config.toml')['ACS_API_KEY'])
#
# File ~/bitbucket/personal_github/american_community_survey/scripts/get_acs_data.py:256, in extract_acs_data(api_key)
#     253 census_output.columns = code_book
#     255 # replace incorrect ACS values with NULLs
# --> 256 census_output.replace(-666666666, pandas.NA, inplace=True)
#     257 census_output.replace(-6666666.66, pandas.NA, inplace=True)
#     259 return census_output
#
# File ~/bitbucket/personal_github/american_community_survey/.venv/lib/python3.10/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~/bitbucket/personal_github/american_community_survey/.venv/lib/python3.10/site-packages/pandas/core/frame.py:5728, in DataFrame.replace(self, to_replace, value, inplace, limit, regex, method)
#    5715 @deprecate_nonkeyword_arguments(
#    5716     version=None, allowed_args=["self", "to_replace", "value"]
#    5717 )
#    (...)
#    5726     method: Literal["pad", "ffill", "bfill"] | lib.NoDefault = lib.no_default,
#    5727 ) -> DataFrame | None:
# -> 5728     return super().replace(
#    5729         to_replace=to_replace,
#    5730         value=value,
#    5731         inplace=inplace,
#    5732         limit=limit,
#    5733         regex=regex,
#    5734         method=method,
#    5735     )
#
# File ~/bitbucket/personal_github/american_community_survey/.venv/lib/python3.10/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~/bitbucket/personal_github/american_community_survey/.venv/lib/python3.10/site-packages/pandas/core/generic.py:7280, in NDFrame.replace(self, to_replace, value, inplace, limit, regex, method)
#    7274         new_data = self._mgr.replace_regex(
#    7275             to_replace=to_replace,
#    7276             value=value,
#    7277             inplace=inplace,
#    7278         )
#    7279     else:
# -> 7280         new_data = self._mgr.replace(
#    7281             to_replace=to_replace, value=value, inplace=inplace
#    7282         )
#    7283 else:
#    7284     raise TypeError(
#    7285         f'Invalid "to_replace" type: {repr(type(to_replace).__name__)}'
#    7286     )
#
# File ~/bitbucket/personal_github/american_community_survey/.venv/lib/python3.10/site-packages/pandas/core/internals/managers.py:470, in BaseBlockManager.replace(self, to_replace, value, inplace)
#     468 assert not is_list_like(to_replace)
#     469 assert not is_list_like(value)
# --> 470 return self.apply(
#     471     "replace", to_replace=to_replace, value=value, inplace=inplace
#     472 )
#
# File ~/bitbucket/personal_github/american_community_survey/.venv/lib/python3.10/site-packages/pandas/core/internals/managers.py:352, in BaseBlockManager.apply(self, f, align_keys, ignore_failures, **kwargs)
#     350         applied = b.apply(f, **kwargs)
#     351     else:
# --> 352         applied = getattr(b, f)(**kwargs)
#     353 except (TypeError, NotImplementedError):
#     354     if not ignore_failures:
#
# File ~/bitbucket/personal_github/american_community_survey/.venv/lib/python3.10/site-packages/pandas/core/internals/blocks.py:626, in Block.replace(self, to_replace, value, inplace, mask)
#     623 blocks = []
#     624 for i, nb in enumerate(self._split()):
#     625     blocks.extend(
# --> 626         type(self).replace(
#     627             nb,
#     628             to_replace=to_replace,
#     629             value=value,
#     630             inplace=True,
#     631             mask=mask[i : i + 1],
#     632         )
#     633     )
#     634 return blocks
#
# File ~/bitbucket/personal_github/american_community_survey/.venv/lib/python3.10/site-packages/pandas/core/internals/blocks.py:614, in Block.replace(self, to_replace, value, inplace, mask)
#     612     else:
#     613         blk = self.coerce_to_target_dtype(value)
# --> 614     return blk.replace(
#     615         to_replace=to_replace,
#     616         value=value,
#     617         inplace=True,
#     618         mask=mask,
#     619     )
#     621 else:
#     622     # split so that we only upcast where necessary
#     623     blocks = []
#
# File ~/bitbucket/personal_github/american_community_survey/.venv/lib/python3.10/site-packages/pandas/core/internals/blocks.py:614, in Block.replace(self, to_replace, value, inplace, mask)
#     612     else:
#     613         blk = self.coerce_to_target_dtype(value)
# --> 614     return blk.replace(
#     615         to_replace=to_replace,
#     616         value=value,
#     617         inplace=True,
#     618         mask=mask,
#     619     )
#     621 else:
#     622     # split so that we only upcast where necessary
#     623     blocks = []
#
#     [... skipping similar frames: Block.replace at line 614 (2950 times)]
#
# File ~/bitbucket/personal_github/american_community_survey/.venv/lib/python3.10/site-packages/pandas/core/internals/blocks.py:614, in Block.replace(self, to_replace, value, inplace, mask)
#     612     else:
#     613         blk = self.coerce_to_target_dtype(value)
# --> 614     return blk.replace(
#     615         to_replace=to_replace,
#     616         value=value,
#     617         inplace=True,
#     618         mask=mask,
#     619     )
#     621 else:
#     622     # split so that we only upcast where necessary
#     623     blocks = []
#
# File ~/bitbucket/personal_github/american_community_survey/.venv/lib/python3.10/site-packages/pandas/core/internals/blocks.py:613, in Block.replace(self, to_replace, value, inplace, mask)
#     611         blk = self.astype(np.dtype(object))
#     612     else:
# --> 613         blk = self.coerce_to_target_dtype(value)
#     614     return blk.replace(
#     615         to_replace=to_replace,
#     616         value=value,
#     617         inplace=True,
#     618         mask=mask,
#     619     )
#     621 else:
#     622     # split so that we only upcast where necessary
#
# File ~/bitbucket/personal_github/american_community_survey/.venv/lib/python3.10/site-packages/pandas/core/internals/blocks.py:450, in Block.coerce_to_target_dtype(self, other)
#     441 """
#     442 coerce the current block to a dtype compat for other
#     443 we will return a block, possibly object, and not raise
#    (...)
#     446 and will receive the same block
#     447 """
#     448 new_dtype = find_result_type(self.values, other)
# --> 450 return self.astype(new_dtype, copy=False)
#
# File ~/bitbucket/personal_github/american_community_survey/.venv/lib/python3.10/site-packages/pandas/core/internals/blocks.py:526, in Block.astype(self, dtype, copy, errors)
#     508 """
#     509 Coerce to the new dtype.
#     510
#    (...)
#     522 Block
#     523 """
#     524 values = self.values
# --> 526 new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     528 new_values = maybe_coerce_values(new_values)
#     529 newb = self.make_block(new_values)
#
# File ~/bitbucket/personal_github/american_community_survey/.venv/lib/python3.10/site-packages/pandas/core/dtypes/astype.py:299, in astype_array_safe(values, dtype, copy, errors)
#     296     return values.copy()
#     298 try:
# --> 299     new_values = astype_array(values, dtype, copy=copy)
#     300 except (ValueError, TypeError):
#     301     # e.g. astype_nansafe can fail on object-dtype of strings
#     302     #  trying to convert to float
#     303     if errors == "ignore":
#
# File ~/bitbucket/personal_github/american_community_survey/.venv/lib/python3.10/site-packages/pandas/core/dtypes/astype.py:217, in astype_array(values, dtype, copy)
#     214     msg = rf"cannot astype a datetimelike from [{values.dtype}] to [{dtype}]"
#     215     raise TypeError(msg)
# --> 217 if is_datetime64tz_dtype(dtype) and is_datetime64_dtype(values.dtype):
#     218     return astype_dt64_to_dt64tz(values, dtype, copy, via_utc=True)
#     220 if is_dtype_equal(values.dtype, dtype):
#
# File ~/bitbucket/personal_github/american_community_survey/.venv/lib/python3.10/site-packages/pandas/core/dtypes/common.py:390, in is_datetime64tz_dtype(arr_or_dtype)
#     388 if arr_or_dtype is None:
#     389     return False
# --> 390 return DatetimeTZDtype.is_dtype(arr_or_dtype)
#
# File ~/bitbucket/personal_github/american_community_survey/.venv/lib/python3.10/site-packages/pandas/core/dtypes/base.py:312, in ExtensionDtype.is_dtype(cls, dtype)
#     288 """
#     289 Check if we match 'dtype'.
#     290
#    (...)
#     308    conditions is true for ``dtype.dtype``.
#     309 """
#     310 dtype = getattr(dtype, "dtype", dtype)
# --> 312 if isinstance(dtype, (ABCSeries, ABCIndex, ABCDataFrame, np.dtype)):
#     313     # https://github.com/pandas-dev/pandas/issues/22960
#     314     # avoid passing data to `construct_from_string`. This could
#     315     # cause a FutureWarning from numpy about failing elementwise
#     316     # comparison from, e.g., comparing DataFrame == 'category'.
#     317     return False
#     318 elif dtype is None:
#
# File ~/bitbucket/personal_github/american_community_survey/.venv/lib/python3.10/site-packages/pandas/core/dtypes/generic.py:47, in create_pandas_abc_type.<locals>._instancecheck(cls, inst)
#      45 @classmethod  # type: ignore[misc]
#      46 def _instancecheck(cls, inst) -> bool:
# ---> 47     return _check(inst) and not isinstance(inst, type)
#
# File ~/bitbucket/personal_github/american_community_survey/.venv/lib/python3.10/site-packages/pandas/core/dtypes/generic.py:41, in create_pandas_abc_type.<locals>._check(inst)
#      40 def _check(inst):
# ---> 41     return getattr(inst, attr, "_typ") in comp
#
# RecursionError: maximum recursion depth exceeded while calling a Python object

# %%
acs_data_2018.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 acs_data_2018.head()
#
# NameError: name 'acs_data_2018' is not defined
